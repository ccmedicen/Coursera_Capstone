# %% [markdown]
# # Santiago de Chile's Neighborhoods and Infraestructure
# ### Cristian Castro Álvarez
# #### IBM Data Science Certificate - Capstone Project

# %% [markdown]
# #### Objective
# In this project I'll try to cluster Santiago's communes in order to give advise on where to live depending on your income and interests (of venues obtained through Foursquare data). This project is aimed at giving advice to foreigners that want to live in Santiago de Chile (Chile, 2020) and intends to provide information of the city.

# %% [markdown]
# #### Data
#
# The methodology and the data to be used are summarized in the figure below.

# %% [markdown]
# ![Captura%20de%20Pantalla%202020-10-18%20a%20la%28s%29%2017.17.15.png](attachment:Captura%20de%20Pantalla%202020-10-18%20a%20la%28s%29%2017.17.15.png)
